# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="image/download.jpg"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/image/download.jpg: 416x640 1 car, 173.4ms
# Speed: 6.9ms preprocess, 173.4ms inference, 7.4ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image('runs/detect/predict/download.jpg')

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="image/download.jpg"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/image/download.jpg: 416x640 1 car, 358.9ms
# Speed: 13.5ms preprocess, 358.9ms inference, 6.8ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image('runs/segment/predict/download.jpg')

# %%
from ultralytics import YOLO
model=YOLO('yolov8n-seg.pt')
model.predict(source='image/download.jpg')
# Out:
# image 1/1 /content/image/download.jpg: 416x640 1 car, 212.7ms
# Speed: 6.4ms preprocess, 212.7ms inference, 4.2ms postprocess per image at shape (1, 3, 416, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="image/download.jpg"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# image 1/1 /content/image/download.jpg: 224x224 racer 0.63, cab 0.18, sports_car 0.11, grille 0.05, car_mirror 0.01, 20.0ms
# Speed: 39.8ms preprocess, 20.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image('runs/classify/predict/download.jpg')
